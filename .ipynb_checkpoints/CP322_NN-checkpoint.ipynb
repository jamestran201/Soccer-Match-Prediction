# %%
from __future__ import print_function

import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.preprocessing import label_binarize, MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
def neural_net(x):
    layer_1 = tf.add(tf.matmul(x, weights['h1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1)
    
    out_layer = tf.matmul(layer_1, weights['output']) + biases['output']
    return out_layer

def neural_net_2_layers(x):
    layer_1 = tf.add(tf.matmul(x, weights['h1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1)
    
    layer_2 = tf.add(tf.matmul(layer_1, weights['h2']), biases['b2'])
    layer_2 = tf.nn.relu(layer_2)
    
    out_layer = tf.matmul(layer_2, weights['output']) + biases['output']
    return out_layer

# %%
def split_data(file):
    filename = [file]
    record_defaults = [tf.float32] * 75   # Eight required float columns
    dataset = tf.contrib.data.CsvDataset(filename, record_defaults)
    return dataset

# %%
train_df = pd.read_csv("Data/formated.csv")
test_df = pd.read_csv("Data/formatedTesting.csv")

train_df.columns = [col.strip() for col in train_df.columns]
test_df.columns = [col.strip() for col in test_df.columns]

# %%
input_nodes = 72
output_nodes = 3
learning_rate = 0.01

# Delete duplicate columns
del train_df["e1"]
del train_df["e1.1"]
del test_df["e1"]
del test_df["e1.1"]

# Uncomment this block to try out different set of features
feature_subset = ["assist count", "assist count 2", "shots made", "e6", "is goal 2", "s1.1",
                            "e6.1", "is goal", "e4", "e2", "shots made 2", "s2.1", "e2.1", "target Feature"]
train_df = train_df.loc[:, feature_subset]
test_df = test_df.loc[:, feature_subset]
input_nodes = 13 # maybe 75 for a bias

X = tf.placeholder("float", [None, input_nodes])
Y = tf.placeholder("float", [None, output_nodes])

# Split the dataframe into features and labels arrays
train_features_array = train_df.iloc[:, :-1].values
train_labels_array = train_df.loc[:, "target Feature"].values
train_labels_binarized = label_binarize(train_labels_array, classes=[0,1,2])

test_features_array = test_df.iloc[:, :-1].values
test_labels_array = test_df.loc[:, "target Feature"].values
test_labels_binarized = label_binarize(test_labels_array, classes=[0,1,2])

normalizer = MinMaxScaler((0,1))
normalizer.fit(train_features_array)

train_features_normalized = normalizer.transform(train_features_array)
test_features_normalized = normalizer.transform(test_features_array)

train_features_normalized, vald_features_normalized, train_labels_binarized, vald_labels_binarized = train_test_split(train_features_normalized, train_labels_binarized, test_size=0.10, random_state=20)
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ## Tuning network with 1 hidden layer

# %%
total_batch = train_features_array.shape[0]
max_validation_accuracy = 0
optimal_weights = {}
optimal_n_units = 0

n_layer_one_units = [i for i in range(2, 21, 2)]
accuracies = {}

for n_unit_1 in n_layer_one_units:
    print("Trying {} units in layer 1".format(n_unit_1))

    weights = {
        'h1': tf.Variable(tf.random_normal([input_nodes, n_unit_1]), name="h1"),
        'output': tf.Variable(tf.random_normal([n_unit_1, output_nodes]), name="output_weights")
    }

    biases = {
        'b1': tf.Variable(tf.random_normal([n_unit_1]), name="b1"),
        'output': tf.Variable(tf.random_normal([output_nodes]), name="output_bias")
    }

    # Construct model
    logits = neural_net(X)

    # Finding the cost of the algorithm
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=Y))

    # Finding optimization of the algorithm
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())

        for i in range(1, 1001):
            avg_cost = 0.0
            _, c = sess.run([optimizer, cost], 
                            feed_dict={
                                X: train_features_normalized, 
                                Y: train_labels_binarized, 
                            })
            avg_cost += c / total_batch

        train_pred = tf.nn.softmax(logits)
        correct_train_prediction = tf.equal(tf.argmax(train_pred, 1), tf.argmax(Y, 1))
        train_accuracy = tf.reduce_mean(tf.cast(correct_train_prediction, "float"))
        print("Training accuracy: ", train_accuracy.eval({X: train_features_normalized, Y: train_labels_binarized}))

        valid_pred = tf.nn.softmax(logits)
        correct_valid_prediction = tf.equal(tf.argmax(valid_pred, 1), tf.argmax(Y, 1))
        valid_accuracy = tf.reduce_mean(tf.cast(correct_valid_prediction, "float"))
        valid_accuracy_value = valid_accuracy.eval({X: vald_features_normalized, Y: vald_labels_binarized})
        accuracies[n_unit_1] = valid_accuracy_value
        print("Validation accuracy: ", valid_accuracy_value)
        
        if max_validation_accuracy < valid_accuracy_value:
            max_validation_accuracy = valid_accuracy_value
            optimal_n_units = n_unit_1
            optimal_weights["h1"] = weights["h1"].eval()
            optimal_weights["output_weights"] = weights["output"].eval()
            optimal_weights["b1"] = biases["b1"].eval()
            optimal_weights["output_bias"] = biases["output"].eval()

    print("------------------------------")

print("Optimal number of units in first hidden layer: {}".format(optimal_n_units))
print("Maximum validation accuracy: {}".format(max_validation_accuracy))
# Out:
# Trying 2 units in layer 1
# Training accuracy:  0.75530523
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 4 units in layer 1
# Training accuracy:  0.7606921
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 6 units in layer 1
# Training accuracy:  0.7605289
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 8 units in layer 1
# Training accuracy:  0.76036566
# Validation accuracy:  0.72393537
# ------------------------------
# Trying 10 units in layer 1
# Training accuracy:  0.7608554
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 12 units in layer 1
# Training accuracy:  0.76199806
# Validation accuracy:  0.72246695
# ------------------------------
# Trying 14 units in layer 1
# Training accuracy:  0.7606921
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 16 units in layer 1
# Training accuracy:  0.76248777
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 18 units in layer 1
# Training accuracy:  0.7608554
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 20 units in layer 1
# Training accuracy:  0.759223
# Validation accuracy:  0.72246695
# ------------------------------
# Optimal number of units in first hidden layer: 6
# Maximum validation accuracy: 0.7298091053962708

# %%
tmp_df = pd.DataFrame({"n_units": n_layer_one_units, "accuracy": list(accuracies.values())})

# %%
sns.relplot(x="n_units", y="accuracy", data=tmp_df, kind="line")
plt.title("Accuracy on validation set")
# Out:
# Text(0.5, 1.0, 'Accuracy on validation set')

# %%
train_df = train_df.loc[:, feature_subset]
test_df = test_df.loc[:, feature_subset]
input_nodes = 13

train_features_array = train_df.iloc[:, :-1].values
train_labels_array = train_df.loc[:, "target Feature"].values
train_labels_binarized = label_binarize(train_labels_array, classes=[0,1,2])
test_features_array = test_df.iloc[:, :-1].values
test_labels_array = test_df.loc[:, "target Feature"].values
test_labels_binarized = label_binarize(test_labels_array, classes=[0,1,2])

normalizer = MinMaxScaler((0,1))
normalizer.fit(train_features_array)

train_features_normalized = normalizer.transform(train_features_array)

weights = {
        'h1': tf.Variable(tf.random_normal([input_nodes, optimal_n_units]), name="h1"),
        'output': tf.Variable(tf.random_normal([optimal_n_units, output_nodes]), name="output_weights")
    }

biases = {
    'b1': tf.Variable(tf.random_normal([optimal_n_units]), name="b1"),
    'output': tf.Variable(tf.random_normal([output_nodes]), name="output_bias")
}

# Construct model
logits = neural_net(X)

# Finding the cost of the algorithm
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=Y))

# Finding optimization of the algorithm
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    for i in range(1, 1001):
        avg_cost = 0.0
        _, c = sess.run([optimizer, cost], 
                        feed_dict={
                            X: train_features_normalized, 
                            Y: train_labels_binarized, 
                        })
        avg_cost += c / total_batch

    train_pred = tf.nn.softmax(logits)
    correct_train_prediction = tf.equal(tf.argmax(train_pred, 1), tf.argmax(Y, 1))
    train_accuracy = tf.reduce_mean(tf.cast(correct_train_prediction, "float"))
    print("Training accuracy: ", train_accuracy.eval({X: train_features_normalized, Y: train_labels_binarized}))

    test_pred = tf.nn.softmax(logits)
    correct_test_prediction = tf.equal(tf.argmax(test_pred, 1), tf.argmax(Y, 1))
    test_accuracy = tf.reduce_mean(tf.cast(correct_test_prediction, "float"))
    test_accuracy_value = test_accuracy.eval({X: test_features_normalized, Y: test_labels_binarized})
    print("Test accuracy: ", test_accuracy_value)
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Training accuracy:  0.75730866
# Test accuracy:  0.7485664

# %% [markdown]
# ## Tuning network with 2 hidden layers

# %%
total_batch = train_features_array.shape[0]
max_validation_accuracy = 0
optimal_weights = {}
optimal_n_units_1 = 0
optimal_n_units_2 = 0

n_layer_one_units = [i for i in range(2, 21, 2)]
n_layer_two_units = [i for i in range(2, 21)]
accuracies = {}

columns = ['Units in hidden layer 1','Units in hidden layer 2', 'Accuracy']
validation_data=[]
train_data=[]
for n_unit_1 in n_layer_one_units:
    for n_unit_2 in n_layer_two_units:
        print("Trying {} units in layer 1 and {} units in layer 2".format(n_unit_1, n_unit_2))

        weights = {
            'h1': tf.Variable(tf.random_normal([input_nodes, n_unit_1]), name="h1"),
            'h2': tf.Variable(tf.random_normal([n_unit_1, n_unit_2])),
            'output': tf.Variable(tf.random_normal([n_unit_2, output_nodes]), name="output_weights")
        }

        biases = {
            'b1': tf.Variable(tf.random_normal([n_unit_1]), name="b1"),
            'b2': tf.Variable(tf.random_normal([n_unit_2])),
            'output': tf.Variable(tf.random_normal([output_nodes]), name="output_bias")
        }

        # Construct model
        logits = neural_net_2_layers(X)

        # Finding the cost of the algorithm
        cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=Y))

        # Finding optimization of the algorithm
        optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())

            for i in range(1, 1001):
                avg_cost = 0.0
                _, c = sess.run([optimizer, cost], 
                                feed_dict={
                                    X: train_features_normalized, 
                                    Y: train_labels_binarized, 
                                })
                avg_cost += c / total_batch
                
            train_pred = tf.nn.softmax(logits)
            correct_train_prediction = tf.equal(tf.argmax(train_pred, 1), tf.argmax(Y, 1))
            train_accuracy = tf.reduce_mean(tf.cast(correct_train_prediction, "float"))
            accuracy = train_accuracy.eval({X: train_features_normalized, Y: train_labels_binarized})
            print("Training accuracy: ", accuracy)
            train_data.append([n_unit_1,n_unit_2,accuracy])
            
            valid_pred = tf.nn.softmax(logits)
            correct_valid_prediction = tf.equal(tf.argmax(valid_pred, 1), tf.argmax(Y, 1))
            valid_accuracy = tf.reduce_mean(tf.cast(correct_valid_prediction, "float"))
            valid_accuracy_value = valid_accuracy.eval({X: vald_features_normalized, Y: vald_labels_binarized})
            accuracies[(n_unit_1, n_unit_2)] = valid_accuracy_value
            print("Validation accuracy: ", valid_accuracy_value)
            validation_data.append([n_unit_1,n_unit_2,valid_accuracy_value])
            
            if max_validation_accuracy < valid_accuracy_value:
                max_validation_accuracy = valid_accuracy_value
                optimal_n_units_1 = n_unit_1
                optimal_n_units_2 = n_unit_2
                optimal_weights["h1"] = weights["h1"].eval()
                optimal_weights["h2"] = weights["h2"].eval()
                optimal_weights["output_weights"] = weights["output"].eval()
                optimal_weights["b1"] = biases["b1"].eval()
                optimal_weights["b2"] = biases["b1"].eval()
                optimal_weights["output_bias"] = biases["output"].eval()

        print("------------------------------")

print("Optimal number of units in first hidden layer: {}".format(optimal_n_units_1))
print("Optimal number of units in second hidden layer: {}".format(optimal_n_units_2))
print("Maximum validation accuracy: {}".format(max_validation_accuracy))
# Out:
# Trying 2 units in layer 1 and 2 units in layer 2
# Training accuracy:  0.7561334
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 2 units in layer 1 and 3 units in layer 2
# Training accuracy:  0.75716174
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 2 units in layer 1 and 4 units in layer 2
# Training accuracy:  0.74555606
# Validation accuracy:  0.7107195
# ------------------------------
# Trying 2 units in layer 1 and 5 units in layer 2
# Training accuracy:  0.7546643
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 2 units in layer 1 and 6 units in layer 2
# Training accuracy:  0.75730866
# Validation accuracy:  0.7180617
# ------------------------------
# Trying 2 units in layer 1 and 7 units in layer 2
# Training accuracy:  0.756721
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 2 units in layer 1 and 8 units in layer 2
# Training accuracy:  0.7570148
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 2 units in layer 1 and 9 units in layer 2
# Training accuracy:  0.7564272
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 2 units in layer 1 and 10 units in layer 2
# Training accuracy:  0.7578963
# Validation accuracy:  0.72393537
# ------------------------------
# Trying 2 units in layer 1 and 11 units in layer 2
# Training accuracy:  0.7558396
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 2 units in layer 1 and 12 units in layer 2
# Training accuracy:  0.7506978
# Validation accuracy:  0.72246695
# ------------------------------
# Trying 2 units in layer 1 and 13 units in layer 2
# Training accuracy:  0.7534891
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 2 units in layer 1 and 14 units in layer 2
# Training accuracy:  0.755105
# Validation accuracy:  0.72393537
# ------------------------------
# Trying 2 units in layer 1 and 15 units in layer 2
# Training accuracy:  0.756721
# Validation accuracy:  0.72393537
# ------------------------------
# Trying 2 units in layer 1 and 16 units in layer 2
# Training accuracy:  0.7539298
# Validation accuracy:  0.7209985
# ------------------------------
# Trying 2 units in layer 1 and 17 units in layer 2
# Training accuracy:  0.7531952
# Validation accuracy:  0.7209985
# ------------------------------
# Trying 2 units in layer 1 and 18 units in layer 2
# Training accuracy:  0.75128543
# Validation accuracy:  0.7209985
# ------------------------------
# Trying 2 units in layer 1 and 19 units in layer 2
# Training accuracy:  0.75525194
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 2 units in layer 1 and 20 units in layer 2
# Training accuracy:  0.7546643
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 4 units in layer 1 and 2 units in layer 2
# Training accuracy:  0.7564272
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 4 units in layer 1 and 3 units in layer 2
# Training accuracy:  0.7561334
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 4 units in layer 1 and 4 units in layer 2
# Training accuracy:  0.75525194
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 4 units in layer 1 and 5 units in layer 2
# Training accuracy:  0.75451744
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 4 units in layer 1 and 6 units in layer 2
# Training accuracy:  0.7558396
# Validation accuracy:  0.72393537
# ------------------------------
# Trying 4 units in layer 1 and 7 units in layer 2
# Training accuracy:  0.7581901
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 4 units in layer 1 and 8 units in layer 2
# Training accuracy:  0.7596592
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 4 units in layer 1 and 9 units in layer 2
# Training accuracy:  0.7561334
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 4 units in layer 1 and 10 units in layer 2
# Training accuracy:  0.7570148
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 4 units in layer 1 and 11 units in layer 2
# Training accuracy:  0.7574556
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 4 units in layer 1 and 12 units in layer 2
# Training accuracy:  0.7570148
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 4 units in layer 1 and 13 units in layer 2
# Training accuracy:  0.7570148
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 4 units in layer 1 and 14 units in layer 2
# Training accuracy:  0.75686795
# Validation accuracy:  0.73421437
# ------------------------------
# Trying 4 units in layer 1 and 15 units in layer 2
# Training accuracy:  0.75378287
# Validation accuracy:  0.72393537
# ------------------------------
# Trying 4 units in layer 1 and 16 units in layer 2
# Training accuracy:  0.755105
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 4 units in layer 1 and 17 units in layer 2
# Training accuracy:  0.756721
# Validation accuracy:  0.72393537
# ------------------------------
# Trying 4 units in layer 1 and 18 units in layer 2
# Training accuracy:  0.75730866
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 4 units in layer 1 and 19 units in layer 2
# Training accuracy:  0.7574556
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 4 units in layer 1 and 20 units in layer 2
# Training accuracy:  0.7581901
# Validation accuracy:  0.73715127
# ------------------------------
# Trying 6 units in layer 1 and 2 units in layer 2
# Training accuracy:  0.5880711
# Validation accuracy:  0.56828195
# ------------------------------
# Trying 6 units in layer 1 and 3 units in layer 2
# Training accuracy:  0.7577494
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 6 units in layer 1 and 4 units in layer 2
# Training accuracy:  0.7570148
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 6 units in layer 1 and 5 units in layer 2
# Training accuracy:  0.7564272
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 6 units in layer 1 and 6 units in layer 2
# Training accuracy:  0.7558396
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 6 units in layer 1 and 7 units in layer 2
# Training accuracy:  0.75730866
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 6 units in layer 1 and 8 units in layer 2
# Training accuracy:  0.7570148
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 6 units in layer 1 and 9 units in layer 2
# Training accuracy:  0.7564272
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 6 units in layer 1 and 10 units in layer 2
# Training accuracy:  0.75760245
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 6 units in layer 1 and 11 units in layer 2
# Training accuracy:  0.7570148
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 6 units in layer 1 and 12 units in layer 2
# Training accuracy:  0.7546643
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 6 units in layer 1 and 13 units in layer 2
# Training accuracy:  0.7559865
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 6 units in layer 1 and 14 units in layer 2
# Training accuracy:  0.7564272
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 6 units in layer 1 and 15 units in layer 2
# Training accuracy:  0.75760245
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 6 units in layer 1 and 16 units in layer 2
# Training accuracy:  0.7564272
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 6 units in layer 1 and 17 units in layer 2
# Training accuracy:  0.75760245
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 6 units in layer 1 and 18 units in layer 2
# Training accuracy:  0.75686795
# Validation accuracy:  0.7400881
# ------------------------------
# Trying 6 units in layer 1 and 19 units in layer 2
# Training accuracy:  0.7561334
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 6 units in layer 1 and 20 units in layer 2
# Training accuracy:  0.75363594
# Validation accuracy:  0.7195301
# ------------------------------
# Trying 8 units in layer 1 and 2 units in layer 2
# Training accuracy:  0.7574556
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 8 units in layer 1 and 3 units in layer 2
# Training accuracy:  0.7564272
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 8 units in layer 1 and 4 units in layer 2
# Training accuracy:  0.755105
# Validation accuracy:  0.73421437
# ------------------------------
# Trying 8 units in layer 1 and 5 units in layer 2
# Training accuracy:  0.7581901
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 8 units in layer 1 and 6 units in layer 2
# Training accuracy:  0.75995296
# Validation accuracy:  0.73421437
# ------------------------------
# Trying 8 units in layer 1 and 7 units in layer 2
# Training accuracy:  0.75760245
# Validation accuracy:  0.7209985
# ------------------------------
# Trying 8 units in layer 1 and 8 units in layer 2
# Training accuracy:  0.7586308
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 8 units in layer 1 and 9 units in layer 2
# Training accuracy:  0.75892466
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 8 units in layer 1 and 10 units in layer 2
# Training accuracy:  0.75539887
# Validation accuracy:  0.72246695
# ------------------------------
# Trying 8 units in layer 1 and 11 units in layer 2
# Training accuracy:  0.76083446
# Validation accuracy:  0.73421437
# ------------------------------
# Trying 8 units in layer 1 and 12 units in layer 2
# Training accuracy:  0.7596592
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 8 units in layer 1 and 13 units in layer 2
# Training accuracy:  0.7602468
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 8 units in layer 1 and 14 units in layer 2
# Training accuracy:  0.7578963
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 8 units in layer 1 and 15 units in layer 2
# Training accuracy:  0.75804317
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 8 units in layer 1 and 16 units in layer 2
# Training accuracy:  0.75730866
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 8 units in layer 1 and 17 units in layer 2
# Training accuracy:  0.75892466
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 8 units in layer 1 and 18 units in layer 2
# Training accuracy:  0.7577494
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 8 units in layer 1 and 19 units in layer 2
# Training accuracy:  0.75951225
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 8 units in layer 1 and 20 units in layer 2
# Training accuracy:  0.7562803
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 10 units in layer 1 and 2 units in layer 2
# Training accuracy:  0.7581901
# Validation accuracy:  0.72246695
# ------------------------------
# Trying 10 units in layer 1 and 3 units in layer 2
# Training accuracy:  0.7602468
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 10 units in layer 1 and 4 units in layer 2
# Training accuracy:  0.7602468
# Validation accuracy:  0.7386197
# ------------------------------
# Trying 10 units in layer 1 and 5 units in layer 2
# Training accuracy:  0.75716174
# Validation accuracy:  0.72246695
# ------------------------------
# Trying 10 units in layer 1 and 6 units in layer 2
# Training accuracy:  0.7598061
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 10 units in layer 1 and 7 units in layer 2
# Training accuracy:  0.7558396
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 10 units in layer 1 and 8 units in layer 2
# Training accuracy:  0.75730866
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 10 units in layer 1 and 9 units in layer 2
# Training accuracy:  0.75730866
# Validation accuracy:  0.7209985
# ------------------------------
# Trying 10 units in layer 1 and 10 units in layer 2
# Training accuracy:  0.76083446
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 10 units in layer 1 and 11 units in layer 2
# Training accuracy:  0.75760245
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 10 units in layer 1 and 12 units in layer 2
# Training accuracy:  0.7584839
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 10 units in layer 1 and 13 units in layer 2
# Training accuracy:  0.7578963
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 10 units in layer 1 and 14 units in layer 2
# Training accuracy:  0.76083446
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 10 units in layer 1 and 15 units in layer 2
# Training accuracy:  0.75686795
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 10 units in layer 1 and 16 units in layer 2
# Training accuracy:  0.758337
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 10 units in layer 1 and 17 units in layer 2
# Training accuracy:  0.75995296
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 10 units in layer 1 and 18 units in layer 2
# Training accuracy:  0.7581901
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 10 units in layer 1 and 19 units in layer 2
# Training accuracy:  0.756721
# Validation accuracy:  0.73421437
# ------------------------------
# Trying 10 units in layer 1 and 20 units in layer 2
# Training accuracy:  0.75760245
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 12 units in layer 1 and 2 units in layer 2
# Training accuracy:  0.7596592
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 12 units in layer 1 and 3 units in layer 2
# Training accuracy:  0.7598061
# Validation accuracy:  0.72393537
# ------------------------------
# Trying 12 units in layer 1 and 4 units in layer 2
# Training accuracy:  0.7558396
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 12 units in layer 1 and 5 units in layer 2
# Training accuracy:  0.75716174
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 12 units in layer 1 and 6 units in layer 2
# Training accuracy:  0.76068753
# Validation accuracy:  0.7386197
# ------------------------------
# Trying 12 units in layer 1 and 7 units in layer 2
# Training accuracy:  0.76039374
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 12 units in layer 1 and 8 units in layer 2
# Training accuracy:  0.756721
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 12 units in layer 1 and 9 units in layer 2
# Training accuracy:  0.758337
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 12 units in layer 1 and 10 units in layer 2
# Training accuracy:  0.7565741
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 12 units in layer 1 and 11 units in layer 2
# Training accuracy:  0.75892466
# Validation accuracy:  0.72246695
# ------------------------------
# Trying 12 units in layer 1 and 12 units in layer 2
# Training accuracy:  0.76083446
# Validation accuracy:  0.73715127
# ------------------------------
# Trying 12 units in layer 1 and 13 units in layer 2
# Training accuracy:  0.7578963
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 12 units in layer 1 and 14 units in layer 2
# Training accuracy:  0.75921845
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 12 units in layer 1 and 15 units in layer 2
# Training accuracy:  0.7593654
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 12 units in layer 1 and 16 units in layer 2
# Training accuracy:  0.75877774
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 12 units in layer 1 and 17 units in layer 2
# Training accuracy:  0.7596592
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 12 units in layer 1 and 18 units in layer 2
# Training accuracy:  0.758337
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 12 units in layer 1 and 19 units in layer 2
# Training accuracy:  0.7570148
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 12 units in layer 1 and 20 units in layer 2
# Training accuracy:  0.75877774
# Validation accuracy:  0.73421437
# ------------------------------
# Trying 14 units in layer 1 and 2 units in layer 2
# Training accuracy:  0.7558396
# Validation accuracy:  0.73421437
# ------------------------------
# Trying 14 units in layer 1 and 3 units in layer 2
# Training accuracy:  0.7565741
# Validation accuracy:  0.73421437
# ------------------------------
# Trying 14 units in layer 1 and 4 units in layer 2
# Training accuracy:  0.7590715
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 14 units in layer 1 and 5 units in layer 2
# Training accuracy:  0.758337
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 14 units in layer 1 and 6 units in layer 2
# Training accuracy:  0.75730866
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 14 units in layer 1 and 7 units in layer 2
# Training accuracy:  0.7577494
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 14 units in layer 1 and 8 units in layer 2
# Training accuracy:  0.7581901
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 14 units in layer 1 and 9 units in layer 2
# Training accuracy:  0.76274425
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 14 units in layer 1 and 10 units in layer 2
# Training accuracy:  0.75730866
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 14 units in layer 1 and 11 units in layer 2
# Training accuracy:  0.76083446
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 14 units in layer 1 and 12 units in layer 2
# Training accuracy:  0.75995296
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 14 units in layer 1 and 13 units in layer 2
# Training accuracy:  0.75716174
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 14 units in layer 1 and 14 units in layer 2
# Training accuracy:  0.75760245
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 14 units in layer 1 and 15 units in layer 2
# Training accuracy:  0.76039374
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 14 units in layer 1 and 16 units in layer 2
# Training accuracy:  0.7593654
# Validation accuracy:  0.7400881
# ------------------------------
# Trying 14 units in layer 1 and 17 units in layer 2
# Training accuracy:  0.7609813
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 14 units in layer 1 and 18 units in layer 2
# Training accuracy:  0.75877774
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 14 units in layer 1 and 19 units in layer 2
# Training accuracy:  0.7600999
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 14 units in layer 1 and 20 units in layer 2
# Training accuracy:  0.7578963
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 16 units in layer 1 and 2 units in layer 2
# Training accuracy:  0.7577494
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 16 units in layer 1 and 3 units in layer 2
# Training accuracy:  0.5880711
# Validation accuracy:  0.56828195
# ------------------------------
# Trying 16 units in layer 1 and 4 units in layer 2
# Training accuracy:  0.5880711
# Validation accuracy:  0.56828195
# ------------------------------
# Trying 16 units in layer 1 and 5 units in layer 2
# Training accuracy:  0.75877774
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 16 units in layer 1 and 6 units in layer 2
# Training accuracy:  0.758337
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 16 units in layer 1 and 7 units in layer 2
# Training accuracy:  0.75921845
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 16 units in layer 1 and 8 units in layer 2
# Training accuracy:  0.75378287
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 16 units in layer 1 and 9 units in layer 2
# Training accuracy:  0.75686795
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 16 units in layer 1 and 10 units in layer 2
# Training accuracy:  0.7628911
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 16 units in layer 1 and 11 units in layer 2
# Training accuracy:  0.7637726
# Validation accuracy:  0.73715127
# ------------------------------
# Trying 16 units in layer 1 and 12 units in layer 2
# Training accuracy:  0.76156896
# Validation accuracy:  0.7488987
# ------------------------------
# Trying 16 units in layer 1 and 13 units in layer 2
# Training accuracy:  0.75716174
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 16 units in layer 1 and 14 units in layer 2
# Training accuracy:  0.75760245
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 16 units in layer 1 and 15 units in layer 2
# Training accuracy:  0.7565741
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 16 units in layer 1 and 16 units in layer 2
# Training accuracy:  0.7598061
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 16 units in layer 1 and 17 units in layer 2
# Training accuracy:  0.7596592
# Validation accuracy:  0.72246695
# ------------------------------
# Trying 16 units in layer 1 and 18 units in layer 2
# Training accuracy:  0.7600999
# Validation accuracy:  0.73715127
# ------------------------------
# Trying 16 units in layer 1 and 19 units in layer 2
# Training accuracy:  0.75995296
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 16 units in layer 1 and 20 units in layer 2
# Training accuracy:  0.7612752
# Validation accuracy:  0.73421437
# ------------------------------
# Trying 18 units in layer 1 and 2 units in layer 2
# Training accuracy:  0.7590715
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 18 units in layer 1 and 3 units in layer 2
# Training accuracy:  0.7574556
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 18 units in layer 1 and 4 units in layer 2
# Training accuracy:  0.75877774
# Validation accuracy:  0.73715127
# ------------------------------
# Trying 18 units in layer 1 and 5 units in layer 2
# Training accuracy:  0.76156896
# Validation accuracy:  0.73421437
# ------------------------------
# Trying 18 units in layer 1 and 6 units in layer 2
# Training accuracy:  0.7578963
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 18 units in layer 1 and 7 units in layer 2
# Training accuracy:  0.7593654
# Validation accuracy:  0.7415565
# ------------------------------
# Trying 18 units in layer 1 and 8 units in layer 2
# Training accuracy:  0.7578963
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 18 units in layer 1 and 9 units in layer 2
# Training accuracy:  0.7590715
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 18 units in layer 1 and 10 units in layer 2
# Training accuracy:  0.7578963
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 18 units in layer 1 and 11 units in layer 2
# Training accuracy:  0.76347876
# Validation accuracy:  0.74743026
# ------------------------------
# Trying 18 units in layer 1 and 12 units in layer 2
# Training accuracy:  0.76083446
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 18 units in layer 1 and 13 units in layer 2
# Training accuracy:  0.7600999
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 18 units in layer 1 and 14 units in layer 2
# Training accuracy:  0.7605406
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 18 units in layer 1 and 15 units in layer 2
# Training accuracy:  0.7548112
# Validation accuracy:  0.73421437
# ------------------------------
# Trying 18 units in layer 1 and 16 units in layer 2
# Training accuracy:  0.7590715
# Validation accuracy:  0.73421437
# ------------------------------
# Trying 18 units in layer 1 and 17 units in layer 2
# Training accuracy:  0.7584839
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 18 units in layer 1 and 18 units in layer 2
# Training accuracy:  0.75892466
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 18 units in layer 1 and 19 units in layer 2
# Training accuracy:  0.76083446
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 18 units in layer 1 and 20 units in layer 2
# Training accuracy:  0.7643602
# Validation accuracy:  0.73715127
# ------------------------------
# Trying 20 units in layer 1 and 2 units in layer 2
# Training accuracy:  0.7561334
# Validation accuracy:  0.72687227
# ------------------------------
# Trying 20 units in layer 1 and 3 units in layer 2
# Training accuracy:  0.7584839
# Validation accuracy:  0.72540385
# ------------------------------
# Trying 20 units in layer 1 and 4 units in layer 2
# Training accuracy:  0.75921845
# Validation accuracy:  0.73715127
# ------------------------------
# Trying 20 units in layer 1 and 5 units in layer 2
# Training accuracy:  0.75921845
# Validation accuracy:  0.7298091
# ------------------------------
# Trying 20 units in layer 1 and 6 units in layer 2
# Training accuracy:  0.76068753
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 20 units in layer 1 and 7 units in layer 2
# Training accuracy:  0.76230353
# Validation accuracy:  0.7283407
# ------------------------------
# Trying 20 units in layer 1 and 8 units in layer 2
# Training accuracy:  0.7558396
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 20 units in layer 1 and 9 units in layer 2
# Training accuracy:  0.7639195
# Validation accuracy:  0.74449337
# ------------------------------
# Trying 20 units in layer 1 and 10 units in layer 2
# Training accuracy:  0.75877774
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 20 units in layer 1 and 11 units in layer 2
# Training accuracy:  0.76303804
# Validation accuracy:  0.73715127
# ------------------------------
# Trying 20 units in layer 1 and 12 units in layer 2
# Training accuracy:  0.7617159
# Validation accuracy:  0.73274595
# ------------------------------
# Trying 20 units in layer 1 and 13 units in layer 2
# Training accuracy:  0.7642133
# Validation accuracy:  0.7400881
# ------------------------------
# Trying 20 units in layer 1 and 14 units in layer 2
# Training accuracy:  0.76142204
# Validation accuracy:  0.73568285
# ------------------------------
# Trying 20 units in layer 1 and 15 units in layer 2
# Training accuracy:  0.7625973
# Validation accuracy:  0.73715127
# ------------------------------
# Trying 20 units in layer 1 and 16 units in layer 2
# Training accuracy:  0.7699427
# Validation accuracy:  0.74743026
# ------------------------------
# Trying 20 units in layer 1 and 17 units in layer 2
# Training accuracy:  0.76582927
# Validation accuracy:  0.74302495
# ------------------------------
# Trying 20 units in layer 1 and 18 units in layer 2
# Training accuracy:  0.76156896
# Validation accuracy:  0.7312775
# ------------------------------
# Trying 20 units in layer 1 and 19 units in layer 2
# Training accuracy:  0.76156896
# Validation accuracy:  0.73421437
# ------------------------------
# Trying 20 units in layer 1 and 20 units in layer 2
# Training accuracy:  0.75892466
# Validation accuracy:  0.73715127
# ------------------------------
# Optimal number of units in first hidden layer: 16
# Optimal number of units in second hidden layer: 12
# Maximum validation accuracy: 0.7488986849784851

# %%
train_result_df = pd.DataFrame(train_data, columns=columns)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(train_result_df['Units in hidden layer 1'], train_result_df['Units in hidden layer 2'], train_result_df['Accuracy'], c='skyblue', s=60)
ax.view_init(30, 185)
plt.title("Training data accuracy for 2 hidden layers")
plt.xlabel('Number of units in hidden layer 1')
plt.ylabel('Number of units in hidden layer 2')
plt.show()

# %%
test_result_df = pd.DataFrame(validation_data, columns=columns)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(test_result_df['Units in hidden layer 1'], test_result_df['Units in hidden layer 2'], test_result_df['Accuracy'], c='skyblue', s=60)
ax.view_init(30, 185)
plt.title("Validation data accuracy for 2 hidden layers")
plt.xlabel('Number of units in hidden layer 1')
plt.ylabel('Number of units in hidden layer 2')
plt.show()

# %%
train_df = train_df.loc[:, feature_subset]
test_df = test_df.loc[:, feature_subset]
input_nodes = 13 # maybe 75 for a bias

train_features_array = train_df.iloc[:, :-1].values
train_labels_array = train_df.loc[:, "target Feature"].values
train_labels_binarized = label_binarize(train_labels_array, classes=[0,1,2])

normalizer = MinMaxScaler((0,1))
normalizer.fit(train_features_array)

train_features_normalized = normalizer.transform(train_features_array)
weights = {
    'h1': tf.Variable(tf.random_normal([input_nodes, optimal_n_units_1]), name="h1"),
    'h2': tf.Variable(tf.random_normal([optimal_n_units_1, optimal_n_units_2])),
    'output': tf.Variable(tf.random_normal([optimal_n_units_2, output_nodes]), name="output_weights")
}

biases = {
    'b1': tf.Variable(tf.random_normal([optimal_n_units_1]), name="b1"),
    'b2': tf.Variable(tf.random_normal([optimal_n_units_2])),
    'output': tf.Variable(tf.random_normal([output_nodes]), name="output_bias")
}

# Construct model
logits = neural_net_2_layers(X)

# Finding the cost of the algorithm
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=Y))

# Finding optimization of the algorithm
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    for i in range(1, 1001):
        avg_cost = 0.0
        _, c = sess.run([optimizer, cost], 
                        feed_dict={
                            X: train_features_normalized, 
                            Y: train_labels_binarized, 
                        })
        avg_cost += c / total_batch

    train_pred = tf.nn.softmax(logits)
    correct_train_prediction = tf.equal(tf.argmax(train_pred, 1), tf.argmax(Y, 1))
    train_accuracy = tf.reduce_mean(tf.cast(correct_train_prediction, "float"))
    print("Training accuracy: ", train_accuracy.eval({X: train_features_normalized, Y: train_labels_binarized}))
          
    test_pred = tf.nn.softmax(logits)
    correct_test_prediction = tf.equal(tf.argmax(test_pred, 1), tf.argmax(Y, 1))
    test_accuracy = tf.reduce_mean(tf.cast(correct_test_prediction, "float"))
    print("Test accuracy: ", test_accuracy.eval({X: test_features_normalized, Y: test_labels_binarized}))
# Out:
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# Training accuracy:  0.7633319
# Test accuracy:  0.74459636
